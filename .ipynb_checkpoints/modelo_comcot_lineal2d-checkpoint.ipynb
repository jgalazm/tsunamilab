# %% [markdown]
# 1. <a href="L2D"> Modelo </a>
#
# 2. <a href="#caso1" >Caso 1</a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import time
# %matplotlib inline

# %% [markdown]
# <a id="L2D"> </a>
#  # COMCOT  lineal 2D

# %%
def simulation(x,h,eta,p,q,rx,ry,dx,dy,cfl,nt,gx):
    dp1 = np.zeros_like(x)
    dp2 = np.zeros_like(x)
    dq1 = np.zeros_like(x)
    dq2 = np.zeros_like(x)

    zdepth = np.zeros_like(eta)
    zdepth[0,:,:] = eta[0,:,:]+h

    t0 = time.clock()
    for n in range(nt-1):


    #     eta[n+1,1:-1,1:-1] = eta[n,1:-1,1:-1] - rx*(p[n,1:-1,1:-1]-p[n,:-2,1:-1]) \
    #                                         -ry*(q[n,1:-1,1:-1]-q[n,1:-1,:-2])
    #     zdepth[n+1,1:-1,1:-1] = eta[n+1,1:-1,1:-1] + h[1:-1,1:-1]

    #     dp1 = 0.25*(zdepth[n+1,:,:]+zdepth[n,:,:]+zdepth[n+1,ip1,:]+zdepth[n,ip1,:])
    #     dp2 = 0.5*(zdepth[n+1,:,:]+zdepth[n+1,ip1,:])
    #     dq1 = 0.25*(zdepth[n+1,:,:]+zdepth[n,:,:]+zdepth[n+1,:,jp1]+zdepth[n,:,jp1])
    #     dq2 = 0.5*(zdepth[n+1,:,:]+zdepth[n+1,:,jp1])

        ## Mas Loop
        for i in range(1, nx-1):
            for j in range(1, ny-1):
                zzz = eta[n,i,j] - rx*(p[n,i,j]-p[n,i-1,j]) \
                               - ry*(q[n,i,j]-q[n,i,j-1])
                DD = zzz + h[i,j]
                zdepth[n+1,i,j] = DD
                eta[n+1,i,j] = zzz    


        # Calculate total water depth and total water depth a discharge point
        for i in range(nx):
            for j in range(ny):
                ip1 = min(nx-1,i+1)
                jp1 = min(ny-1,j+1)            
                im1 = max(0,i-1)
                jm1 = max(0,j-1)

                dp1[i,j] = 0.25*(zdepth[n+1,i,j] + zdepth[n,i,j] + zdepth[n+1,ip1,j] + zdepth[n, ip1, j])
                dp2[i,j] = 0.5*(zdepth[n+1,i,j]+zdepth[n+1,ip1,j])    
                dq1[i,j] = 0.25*(zdepth[n+1,i,j] + zdepth[n,i,j] + zdepth[n+1,i,jp1] + zdepth[n, i, jp1])
                dq2[i,j] = 0.5*(zdepth[n+1,i,j]+zdepth[n+1,i,jp1])    

        # open boundary
        i = 0
        for j in range(1,ny-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                if h[i,j-1]>gx:
                    uh = 0.5*(q[n,i,j]+q[n,i,j-1])
                else:
                    uh = q[n,i,j]
                uu = np.sqrt(uh**2+p[n,i,j]**2)
                zz = uu/cc
                if p[n,i,j]>0:
                    zz = -zz
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]

        i = nx-1
        for j in range(1,ny-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                uh = 0.5*(p[n,i,j]+p[n,i,j-1])
                uu = np.sqrt(uh**2+p[n,i-1,j]**2)
                zz = uu/cc
                if p[n,i-1,j]<0:
                    zz = -zz
                eta[n+1,i,j] = zz     
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]

        j = 0
        for i in range(1,nx-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                uh = 0.5*(p[n,i,j]+p[n,i-1,j])
                uu = np.sqrt(uh**2+q[n,i,j]**2)
                zz = uu/cc
                if q[n,i,j]>0:
                    zz = -zz
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]        

        j = ny-1
        for i in range(1,nx-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                uh = 0.5*(p[n,i,j]+p[n,i-1,j])
                uu = np.sqrt(uh**2+q[n,i,j]**2)
                zz = uu/cc
                if q[n,i-1,j]<0:
                    zz = -zz
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j] 

        i = 0
        j = 0
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i,j]
            qy = q[n,i,j]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx>0 or qy>0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]           

        i = nx-1
        j = 0
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i-1,j]
            qy = q[n,i,j]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx<0 or qy>0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]                 

        i = 0
        j = ny-1
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i,j]
            qy = q[n,i,j-1]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx>0 or qy<0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]

        i = nx-1
        j = ny-1
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i-1,j]
            qy = q[n,i,j-1]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx<0 or qy<0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]               

        # momentum loop

        # momentum in x-direction
        for i in range(1,nx-1):
            for j in range(1,ny-1):
                noflux = False
                #moving boundary
                ip1 = min(nx-1,i+1)
                jp1 = min(ny-1,j+1)
                im1 = max(0,i-1)
                jm1 = max(0,j-1)

                if (zdepth[n+1,i,j]>gx and zdepth[n+1,ip1,j]>gx):
                    dd = dp2[i,j]
                    df = dp1[i,j]
                elif (zdepth[n+1,i,j]>gx and zdepth[n+1,ip1,j]<=gx \
                     and h[ip1,j]+eta[n+1,i,j]>0):
#                     dd = h[ip1,j] + eta[n+1,i,j]
#                     df = dd
                    dd = 0.5*zdepth[n+1,i,j]
                elif (zdepth[n+1,i,j]<=gx and zdepth[n+1,ip1,j]>gx \
                     and h[i,j]+eta[n+1,ip1,j]>0):
                    dd = zdepth[n+1,ip1,j]
#                     dd = h[i,j] + eta[n+1,ip1,j]
#                     df = dd
                else:
                    p[n+1,i,j] = 0.0
                    noflux = True

                #upwind scheme for x direction
                advx = 0.0
                if not noflux:
                    p[n+1,i,j] = p[n,i,j] - 9.81*rx*dd*(eta[n+1,i+1,j]-eta[n+1,i,j]) - \
                             9.81*rx*dd/12.*((eta[n+1,ip1,jp1]-2.*eta[n+1,ip1,j]+eta[n+1,ip1,jm1]) -
                                             (eta[n+1,i,jp1] -2.*eta[n+1,i,j] + eta[n+1,i,jm1]))
                else:
                    p[n+1,i,j] = 0.0


        # momentum in y-direction
        for i in range(1,nx-1):
            for j in range(1,ny-1):
                noflux = False
                #moving boundary
                ip1 = min(nx-1,i+1)
                jp1 = min(ny-1,j+1)
                im1 = max(0,i-1)
                jm1 = max(0,j-1)

                if (zdepth[n+1,i,j]>gx and zdepth[n+1,i,jp1]>gx):
                    dd = dq2[i,j]
                    df = dq1[i,j]
                elif (zdepth[n+1,i,j]>gx and zdepth[n+1,i,jp1]<=gx \
                     and h[i,jp1]+eta[n+1,i,j]>gx):
                    dd = 0.5*zdepth[n+1,i,j]
#                     dd = h[i,jp1] + eta[n+1,i,j]
#                     df = dd
                elif (zdepth[n+1,i,j]<=gx and zdepth[n+1,i,jp1]>gx \
                     and h[i,j]+eta[n+1,i,jp1]>gx):
                    dd = 0.5*zdepth[n+1,i,jp1]
#                     dd = h[i,j] + eta[n+1,i,jp1]
#                     df = dd
                else:
                    q[n+1,i,j] = 0.0
                    noflux = True

                #upwind scheme for x direction
                advy = 0.0
                if not noflux:
                    q[n+1,i,j] = q[n,i,j] - 9.81*ry*dd*(eta[n+1,i,jp1]-eta[n+1,i,j]) - \
                                9.81*ry*dd/12.*((eta[n+1,ip1,jp1]-2*eta[n+1,i,jp1]+eta[n+1,im1,jp1]) - \
                                               (eta[n+1,ip1,j]-2*eta[n+1,i,j]+eta[n+1,im1,j]))           
                else:
                    q[n+1,i,j] = 0.0    
    
        t1 = time.clock()    
        print n*1.0/nt, 'elapsed: %.3f s, estimated %.3f s:'%(t1-t0,(t1-t0)*nt*1.0/(n+1))
    return eta,p,q

# %% [markdown]
# <a id="caso1"></a>
# # Caso de prueba

# %%
nt = 400
ny = 100
nx = 100
y = np.linspace(-200,200,ny)
x = np.linspace(-200,200,nx)
x,y = np.meshgrid(x,y,indexing='ij')
h = np.ones_like(x)*5.
h = np.where(np.abs(x**2+y**2)<=30**2,1.0,h)
# h = np.where(x>=90,-2,h)
# h = np.where(y<=-90,-2,h)
# h = np.where(y>=90,-2,h)

# %%
plt.pcolormesh(x,y,-h)
plt.axis('equal')
plt.title('-h')
plt.colorbar()

# %%
eta = np.zeros((nt,nx,ny))
eta[0,:,:] = 00.5*np.exp(-((y+60)**2+(x+60)**2)/500) ##gaussian bell
eta[0,:,:] = np.where(h>=0,eta[0,:,:],-h)
plt.pcolormesh(x,y,eta[0,:,:],vmax=0.6)
plt.axis('equal')
plt.title(u'$\eta$',fontsize=26)
plt.colorbar()

# %%
p = np.zeros((nt,nx,ny))
q = np.zeros((nt,nx,ny))

# %%
cfl = 0.45
dx = np.diff(x.T)[0,0]
dy = np.diff(y)[0,0]
dt = cfl*min(dx,dy)/np.sqrt(np.max(h)*9.81)
rx = dt/dx
ry = dt/dy
gx = 1e-5
grx = 9.81*dt/dx
gry = 9.81*dt/dy

# %%
print 'finished'
# Out:
# finished

# %%
eta,p,q = simulation(x,h,eta,p,q,rx,ry,dx,dy,cfl,nt,gx)
# Out:
# 0.0 elapsed: 0.191 s, estimated 76.399 s:
# 0.0025 elapsed: 0.375 s, estimated 74.986 s:
# 0.005 elapsed: 0.561 s, estimated 74.824 s:
# 0.0075 elapsed: 0.753 s, estimated 75.290 s:
# 0.01 elapsed: 0.958 s, estimated 76.660 s:
# 0.0125 elapsed: 1.165 s, estimated 77.699 s:
# 0.015 elapsed: 1.354 s, estimated 77.353 s:
# 0.0175 elapsed: 1.540 s, estimated 76.978 s:
# 0.02 elapsed: 1.724 s, estimated 76.619 s:
# 0.0225 elapsed: 1.943 s, estimated 77.720 s:
# 0.025 elapsed: 2.131 s, estimated 77.474 s:
# 0.0275 elapsed: 2.318 s, estimated 77.282 s:
# 0.03 elapsed: 2.508 s, estimated 77.156 s:
# 0.0325 elapsed: 2.697 s, estimated 77.045 s:
# 0.035 elapsed: 2.885 s, estimated 76.929 s:
# 0.0375 elapsed: 3.082 s, estimated 77.043 s:
# 0.04 elapsed: 3.269 s, estimated 76.924 s:
# 0.0425 elapsed: 3.455 s, estimated 76.775 s:
# 0.045 elapsed: 3.641 s, estimated 76.663 s:
# 0.0475 elapsed: 3.832 s, estimated 76.645 s:
# 0.05 elapsed: 4.048 s, estimated 77.108 s:
# 0.0525 elapsed: 4.236 s, estimated 77.011 s:
# 0.055 elapsed: 4.429 s, estimated 77.019 s:
# 0.0575 elapsed: 4.635 s, estimated 77.243 s:
# 0.06 elapsed: 4.828 s, estimated 77.248 s:
# 0.0625 elapsed: 5.016 s, estimated 77.167 s:
# 0.065 elapsed: 5.204 s, estimated 77.092 s:
# 0.0675 elapsed: 5.393 s, estimated 77.038 s:
# 0.07 elapsed: 5.576 s, estimated 76.914 s:
# 0.0725 elapsed: 5.765 s, estimated 76.864 s:
# 0.075 elapsed: 5.957 s, estimated 76.864 s:
# 0.0775 elapsed: 6.151 s, estimated 76.882 s:
# 0.08 elapsed: 6.335 s, estimated 76.792 s:
# 0.0825 elapsed: 6.518 s, estimated 76.684 s:
# 0.085 elapsed: 6.709 s, estimated 76.676 s:
# 0.0875 elapsed: 6.895 s, estimated 76.611 s:
# 0.09 elapsed: 7.098 s, estimated 76.732 s:
# 0.0925 elapsed: 7.283 s, estimated 76.663 s:
# 0.095 elapsed: 7.481 s, estimated 76.729 s:
# 0.0975 elapsed: 7.722 s, estimated 77.224 s:
# 0.1 elapsed: 7.979 s, estimated 77.842 s:
# 0.1025 elapsed: 8.203 s, estimated 78.125 s:
# 0.105 elapsed: 8.421 s, estimated 78.335 s:
# 0.1075 elapsed: 8.601 s, estimated 78.195 s:
# 0.11 elapsed: 8.816 s, estimated 78.364 s:
# 0.1125 elapsed: 9.002 s, estimated 78.275 s:
# 0.115 elapsed: 9.182 s, estimated 78.148 s:
# 0.1175 elapsed: 9.411 s, estimated 78.423 s:
# 0.12 elapsed: 9.601 s, estimated 78.376 s:
# 0.1225 elapsed: 9.822 s, estimated 78.573 s:
# 0.125 elapsed: 10.011 s, estimated 78.514 s:
# 0.1275 elapsed: 10.206 s, estimated 78.504 s:
# 0.13 elapsed: 10.411 s, estimated 78.577 s:
# 0.1325 elapsed: 10.605 s, estimated 78.558 s:
# 0.135 elapsed: 10.797 s, estimated 78.525 s:
# 0.1375 elapsed: 10.988 s, estimated 78.484 s:
# 0.14 elapsed: 11.181 s, estimated 78.466 s:
# 0.1425 elapsed: 11.374 s, estimated 78.445 s:
# 0.145 elapsed: 11.561 s, estimated 78.380 s:
# 0.1475 elapsed: 11.779 s, estimated 78.524 s:
# 0.15 elapsed: 11.970 s, estimated 78.491 s:
# 0.1525 elapsed: 12.182 s, estimated 78.595 s:
# 0.155 elapsed: 12.376 s, estimated 78.575 s:
# 0.1575 elapsed: 12.572 s, estimated 78.573 s:
# 0.16 elapsed: 12.817 s, estimated 78.874 s:
# 0.1625 elapsed: 13.013 s, estimated 78.865 s:
# 0.165 elapsed: 13.220 s, estimated 78.923 s:
# 0.1675 elapsed: 13.427 s, estimated 78.981 s:
# 0.17 elapsed: 13.629 s, estimated 79.010 s:
# 0.1725 elapsed: 13.816 s, estimated 78.950 s:
# 0.175 elapsed: 14.003 s, estimated 78.887 s:
# 0.1775 elapsed: 14.187 s, estimated 78.817 s:
# 0.18 elapsed: 14.435 s, estimated 79.096 s:
# 0.1825 elapsed: 14.659 s, estimated 79.237 s:
# 0.185 elapsed: 14.899 s, estimated 79.461 s:
# 0.1875 elapsed: 15.155 s, estimated 79.762 s:
# 0.19 elapsed: 15.357 s, estimated 79.776 s:
# 0.1925 elapsed: 15.546 s, estimated 79.722 s:
# 0.195 elapsed: 15.747 s, estimated 79.732 s:
# 0.1975 elapsed: 15.946 s, estimated 79.732 s:
# 0.2 elapsed: 16.160 s, estimated 79.803 s:
# 0.2025 elapsed: 16.351 s, estimated 79.761 s:
# 0.205 elapsed: 16.568 s, estimated 79.845 s:
# 0.2075 elapsed: 16.764 s, estimated 79.829 s:
# 0.21 elapsed: 16.982 s, estimated 79.915 s:
# 0.2125 elapsed: 17.233 s, estimated 80.152 s:
# 0.215 elapsed: 17.478 s, estimated 80.361 s:
# 0.2175 elapsed: 17.716 s, estimated 80.527 s:
# 0.22 elapsed: 17.966 s, estimated 80.745 s:
# 0.2225 elapsed: 18.229 s, estimated 81.018 s:
# 0.225 elapsed: 18.522 s, estimated 81.416 s:
# 0.2275 elapsed: 18.774 s, estimated 81.627 s:
# 0.23 elapsed: 18.973 s, estimated 81.606 s:
# 0.2325 elapsed: 19.211 s, estimated 81.750 s:
# 0.235 elapsed: 19.470 s, estimated 81.979 s:
# 0.2375 elapsed: 19.684 s, estimated 82.016 s:
# 0.24 elapsed: 19.905 s, estimated 82.082 s:
# 0.2425 elapsed: 20.113 s, estimated 82.094 s:
# 0.245 elapsed: 20.313 s, estimated 82.073 s:
# 0.2475 elapsed: 20.565 s, estimated 82.258 s:
# 0.25 elapsed: 20.819 s, estimated 82.450 s:
# 0.2525 elapsed: 21.090 s, estimated 82.708 s:
# 0.255 elapsed: 21.273 s, estimated 82.613 s:
# 0.2575 elapsed: 21.468 s, estimated 82.570 s:
# 0.26 elapsed: 21.657 s, estimated 82.503 s:
# 0.2625 elapsed: 21.884 s, estimated 82.580 s:
# 0.265 elapsed: 22.089 s, estimated 82.575 s:
# 0.2675 elapsed: 22.276 s, estimated 82.505 s:
# 0.27 elapsed: 22.469 s, estimated 82.456 s:
# 0.2725 elapsed: 22.671 s, estimated 82.442 s:
# 0.275 elapsed: 22.869 s, estimated 82.410 s:
# 0.2775 elapsed: 23.072 s, estimated 82.399 s:
# 0.28 elapsed: 23.271 s, estimated 82.375 s:
# 0.2825 elapsed: 23.464 s, estimated 82.330 s:
# 0.285 elapsed: 23.661 s, estimated 82.298 s:
# 0.2875 elapsed: 23.855 s, estimated 82.258 s:
# 0.29 elapsed: 24.063 s, estimated 82.266 s:
# 0.2925 elapsed: 24.254 s, estimated 82.217 s:
# 0.295 elapsed: 24.441 s, estimated 82.154 s:
# 0.2975 elapsed: 24.657 s, estimated 82.190 s:
# 0.3 elapsed: 24.868 s, estimated 82.207 s:
# 0.3025 elapsed: 25.076 s, estimated 82.218 s:
# 0.305 elapsed: 25.288 s, estimated 82.237 s:
# 0.3075 elapsed: 25.490 s, estimated 82.224 s:
# 0.31 elapsed: 25.698 s, estimated 82.232 s:
# 0.3125 elapsed: 25.893 s, estimated 82.200 s:
# 0.315 elapsed: 26.085 s, estimated 82.158 s:
# 0.3175 elapsed: 26.283 s, estimated 82.133 s:
# 0.32 elapsed: 26.473 s, estimated 82.087 s:
# 0.3225 elapsed: 26.674 s, estimated 82.074 s:
# 0.325 elapsed: 26.867 s, estimated 82.035 s:
# 0.3275 elapsed: 27.062 s, estimated 82.005 s:
# 0.33 elapsed: 27.250 s, estimated 81.954 s:
# 0.3325 elapsed: 27.433 s, estimated 81.889 s:
# 0.335 elapsed: 27.628 s, estimated 81.860 s:
# 0.3375 elapsed: 27.815 s, estimated 81.808 s:
# 0.34 elapsed: 28.007 s, estimated 81.771 s:
# 0.3425 elapsed: 28.201 s, estimated 81.743 s:
# 0.345 elapsed: 28.387 s, estimated 81.689 s:
# 0.3475 elapsed: 28.572 s, estimated 81.635 s:
# 0.35 elapsed: 28.783 s, estimated 81.654 s:
# 0.3525 elapsed: 28.970 s, estimated 81.605 s:
# 0.355 elapsed: 29.154 s, estimated 81.551 s:
# 0.3575 elapsed: 29.344 s, estimated 81.512 s:
# 0.36 elapsed: 29.532 s, estimated 81.469 s:
# 0.3625 elapsed: 29.737 s, estimated 81.470 s:
# 0.365 elapsed: 29.926 s, estimated 81.430 s:
# 0.3675 elapsed: 30.115 s, estimated 81.391 s:
# 0.37 elapsed: 30.299 s, estimated 81.339 s:
# 0.3725 elapsed: 30.506 s, estimated 81.350 s:
# 0.375 elapsed: 30.705 s, estimated 81.337 s:
# 0.3775 elapsed: 30.891 s, estimated 81.293 s:
# 0.38 elapsed: 31.078 s, estimated 81.250 s:
# 0.3825 elapsed: 31.266 s, estimated 81.211 s:
# 0.385 elapsed: 31.454 s, estimated 81.172 s:
# 0.3875 elapsed: 31.645 s, estimated 81.140 s:
# 0.39 elapsed: 31.843 s, estimated 81.129 s:
# 0.3925 elapsed: 32.082 s, estimated 81.221 s:
# 0.395 elapsed: 32.268 s, estimated 81.176 s:
# 0.3975 elapsed: 32.454 s, estimated 81.135 s:
# 0.4 elapsed: 32.643 s, estimated 81.101 s:
# 0.4025 elapsed: 32.828 s, estimated 81.058 s:
# 0.405 elapsed: 33.018 s, estimated 81.026 s:
# 0.4075 elapsed: 33.209 s, estimated 80.997 s:
# 0.41 elapsed: 33.393 s, estimated 80.953 s:
# 0.4125 elapsed: 33.583 s, estimated 80.922 s:
# 0.415 elapsed: 33.774 s, estimated 80.896 s:
# 0.4175 elapsed: 33.961 s, estimated 80.858 s:
# 0.42 elapsed: 34.148 s, estimated 80.823 s:
# 0.4225 elapsed: 34.338 s, estimated 80.795 s:
# 0.425 elapsed: 34.556 s, estimated 80.832 s:
# 0.4275 elapsed: 34.775 s, estimated 80.872 s:
# 0.43 elapsed: 35.030 s, estimated 80.994 s:
# 0.4325 elapsed: 35.227 s, estimated 80.981 s:
# 0.435 elapsed: 35.442 s, estimated 81.009 s:
# 0.4375 elapsed: 35.719 s, estimated 81.179 s:
# 0.44 elapsed: 35.906 s, estimated 81.144 s:
# 0.4425 elapsed: 36.120 s, estimated 81.168 s:
# 0.445 elapsed: 36.309 s, estimated 81.137 s:
# 0.4475 elapsed: 36.496 s, estimated 81.103 s:
# 0.45 elapsed: 36.683 s, estimated 81.068 s:
# 0.4525 elapsed: 36.894 s, estimated 81.087 s:
# 0.455 elapsed: 37.084 s, estimated 81.057 s:
# 0.4575 elapsed: 37.279 s, estimated 81.041 s:
# 0.46 elapsed: 37.475 s, estimated 81.026 s:
# 0.4625 elapsed: 37.686 s, estimated 81.044 s:
# 0.465 elapsed: 37.888 s, estimated 81.044 s:
# 0.4675 elapsed: 38.090 s, estimated 81.043 s:
# 0.47 elapsed: 38.285 s, estimated 81.026 s:
# 0.4725 elapsed: 38.476 s, estimated 81.002 s:
# 0.475 elapsed: 38.660 s, estimated 80.963 s:
# 0.4775 elapsed: 38.847 s, estimated 80.931 s:
# 0.48 elapsed: 39.035 s, estimated 80.901 s:
# 0.4825 elapsed: 39.219 s, estimated 80.865 s:
# 0.485 elapsed: 39.404 s, estimated 80.830 s:
# 0.4875 elapsed: 39.593 s, estimated 80.802 s:
# 0.49 elapsed: 39.788 s, estimated 80.787 s:
# 0.4925 elapsed: 39.973 s, estimated 80.753 s:
# 0.495 elapsed: 40.159 s, estimated 80.721 s:
# 0.4975 elapsed: 40.345 s, estimated 80.691 s:
# 0.5 elapsed: 40.529 s, estimated 80.655 s:
# 0.5025 elapsed: 40.713 s, estimated 80.621 s:
# 0.505 elapsed: 40.916 s, estimated 80.623 s:
# 0.5075 elapsed: 41.100 s, estimated 80.589 s:
# 0.51 elapsed: 41.282 s, estimated 80.551 s:
# 0.5125 elapsed: 41.475 s, estimated 80.535 s:
# 0.515 elapsed: 41.667 s, estimated 80.516 s:
# 0.5175 elapsed: 41.865 s, estimated 80.509 s:
# 0.52 elapsed: 42.062 s, estimated 80.501 s:
# 0.5225 elapsed: 42.256 s, estimated 80.487 s:
# 0.525 elapsed: 42.446 s, estimated 80.466 s:
# 0.5275 elapsed: 42.635 s, estimated 80.444 s:
# 0.53 elapsed: 42.822 s, estimated 80.417 s:
# 0.5325 elapsed: 43.071 s, estimated 80.507 s:
# 0.535 elapsed: 43.264 s, estimated 80.492 s:
# 0.5375 elapsed: 43.452 s, estimated 80.467 s:
# 0.54 elapsed: 43.639 s, estimated 80.440 s:
# 0.5425 elapsed: 43.832 s, estimated 80.426 s:
# 0.545 elapsed: 44.029 s, estimated 80.418 s:
# 0.5475 elapsed: 44.219 s, estimated 80.398 s:
# 0.55 elapsed: 44.412 s, estimated 80.383 s:
# 0.5525 elapsed: 44.599 s, estimated 80.358 s:
# 0.555 elapsed: 44.781 s, estimated 80.325 s:
# 0.5575 elapsed: 44.962 s, estimated 80.290 s:
# 0.56 elapsed: 45.162 s, estimated 80.287 s:
# 0.5625 elapsed: 45.345 s, estimated 80.257 s:
# 0.565 elapsed: 45.530 s, estimated 80.229 s:
# 0.5675 elapsed: 45.716 s, estimated 80.204 s:
# 0.57 elapsed: 45.900 s, estimated 80.175 s:
# 0.5725 elapsed: 46.084 s, estimated 80.146 s:
# 0.575 elapsed: 46.270 s, estimated 80.121 s:
# 0.5775 elapsed: 46.453 s, estimated 80.092 s:
# 0.58 elapsed: 46.636 s, estimated 80.062 s:
# 0.5825 elapsed: 46.824 s, estimated 80.040 s:
# 0.585 elapsed: 47.008 s, estimated 80.013 s:
# 0.5875 elapsed: 47.191 s, estimated 79.985 s:
# 0.59 elapsed: 47.374 s, estimated 79.955 s:
# 0.5925 elapsed: 47.562 s, estimated 79.936 s:
# 0.595 elapsed: 47.755 s, estimated 79.924 s:
# 0.5975 elapsed: 47.945 s, estimated 79.909 s:
# 0.6 elapsed: 48.134 s, estimated 79.890 s:
# 0.6025 elapsed: 48.316 s, estimated 79.861 s:
# 0.605 elapsed: 48.498 s, estimated 79.832 s:
# 0.6075 elapsed: 48.687 s, estimated 79.815 s:
# 0.61 elapsed: 48.872 s, estimated 79.792 s:
# 0.6125 elapsed: 49.057 s, estimated 79.767 s:
# 0.615 elapsed: 49.248 s, estimated 79.754 s:
# 0.6175 elapsed: 49.447 s, estimated 79.753 s:
# 0.62 elapsed: 49.631 s, estimated 79.728 s:
# 0.6225 elapsed: 49.816 s, estimated 79.705 s:
# 0.625 elapsed: 50.011 s, estimated 79.698 s:
# 0.6275 elapsed: 50.196 s, estimated 79.677 s:
# 0.63 elapsed: 50.382 s, estimated 79.655 s:
# 0.6325 elapsed: 50.567 s, estimated 79.633 s:
# 0.635 elapsed: 50.753 s, estimated 79.613 s:
# 0.6375 elapsed: 50.936 s, estimated 79.588 s:
# 0.64 elapsed: 51.139 s, estimated 79.593 s:
# 0.6425 elapsed: 51.330 s, estimated 79.582 s:
# 0.645 elapsed: 51.524 s, estimated 79.574 s:
# 0.6475 elapsed: 51.712 s, estimated 79.558 s:
# 0.65 elapsed: 51.898 s, estimated 79.538 s:
# 0.6525 elapsed: 52.092 s, estimated 79.530 s:
# 0.655 elapsed: 52.279 s, estimated 79.512 s:
# 0.6575 elapsed: 52.467 s, estimated 79.495 s:
# 0.66 elapsed: 52.654 s, estimated 79.478 s:
# 0.6625 elapsed: 52.843 s, estimated 79.463 s:
# 0.665 elapsed: 53.032 s, estimated 79.449 s:
# 0.6675 elapsed: 53.223 s, estimated 79.437 s:
# 0.67 elapsed: 53.410 s, estimated 79.420 s:
# 0.6725 elapsed: 53.599 s, estimated 79.406 s:
# 0.675 elapsed: 53.787 s, estimated 79.391 s:
# 0.6775 elapsed: 53.976 s, estimated 79.376 s:
# 0.68 elapsed: 54.184 s, estimated 79.390 s:
# 0.6825 elapsed: 54.370 s, estimated 79.373 s:
# 0.685 elapsed: 54.556 s, estimated 79.355 s:
# 0.6875 elapsed: 54.747 s, estimated 79.344 s:
# 0.69 elapsed: 54.939 s, estimated 79.335 s:
# 0.6925 elapsed: 55.132 s, estimated 79.327 s:
# 0.695 elapsed: 55.326 s, estimated 79.321 s:
# 0.6975 elapsed: 55.511 s, estimated 79.301 s:
# 0.7 elapsed: 55.695 s, estimated 79.282 s:
# 0.7025 elapsed: 55.883 s, estimated 79.267 s:
# 0.705 elapsed: 56.071 s, estimated 79.252 s:
# 0.7075 elapsed: 56.288 s, estimated 79.279 s:
# 0.71 elapsed: 56.476 s, estimated 79.264 s:
# 0.7125 elapsed: 56.667 s, estimated 79.255 s:
# 0.715 elapsed: 56.855 s, estimated 79.241 s:
# 0.7175 elapsed: 57.044 s, estimated 79.228 s:
# 0.72 elapsed: 57.243 s, estimated 79.229 s:
# 0.7225 elapsed: 57.431 s, estimated 79.216 s:
# 0.725 elapsed: 57.618 s, estimated 79.200 s:
# 0.7275 elapsed: 57.808 s, estimated 79.189 s:
# 0.73 elapsed: 57.996 s, estimated 79.175 s:
# 0.7325 elapsed: 58.182 s, estimated 79.159 s:
# 0.735 elapsed: 58.375 s, estimated 79.152 s:
# 0.7375 elapsed: 58.569 s, estimated 79.148 s:
# 0.74 elapsed: 58.759 s, estimated 79.137 s:
# 0.7425 elapsed: 58.951 s, estimated 79.128 s:
# 0.745 elapsed: 59.135 s, estimated 79.111 s:
# 0.7475 elapsed: 59.323 s, estimated 79.097 s:
# 0.75 elapsed: 59.510 s, estimated 79.083 s:
# 0.7525 elapsed: 59.697 s, estimated 79.069 s:
# 0.755 elapsed: 59.885 s, estimated 79.056 s:
# 0.7575 elapsed: 60.099 s, estimated 79.078 s:
# 0.76 elapsed: 60.293 s, estimated 79.073 s:
# 0.7625 elapsed: 60.476 s, estimated 79.054 s:
# 0.765 elapsed: 60.660 s, estimated 79.035 s:
# 0.7675 elapsed: 60.844 s, estimated 79.018 s:
# 0.77 elapsed: 61.030 s, estimated 79.003 s:
# 0.7725 elapsed: 61.213 s, estimated 78.985 s:
# 0.775 elapsed: 61.420 s, estimated 78.997 s:
# 0.7775 elapsed: 61.650 s, estimated 79.038 s:
# 0.78 elapsed: 61.906 s, estimated 79.113 s:
# 0.7825 elapsed: 62.126 s, estimated 79.141 s:
# 0.785 elapsed: 62.324 s, estimated 79.141 s:
# 0.7875 elapsed: 62.519 s, estimated 79.139 s:
# 0.79 elapsed: 62.723 s, estimated 79.146 s:
# 0.7925 elapsed: 62.994 s, estimated 79.238 s:
# 0.795 elapsed: 63.205 s, estimated 79.254 s:
# 0.7975 elapsed: 63.411 s, estimated 79.264 s:
# 0.8 elapsed: 63.614 s, estimated 79.270 s:
# 0.8025 elapsed: 63.812 s, estimated 79.269 s:
# 0.805 elapsed: 64.013 s, estimated 79.273 s:
# 0.8075 elapsed: 64.201 s, estimated 79.261 s:
# 0.81 elapsed: 64.387 s, estimated 79.246 s:
# 0.8125 elapsed: 64.572 s, estimated 79.229 s:
# 0.815 elapsed: 64.759 s, estimated 79.216 s:
# 0.8175 elapsed: 64.953 s, estimated 79.210 s:
# 0.82 elapsed: 65.137 s, estimated 79.194 s:
# 0.8225 elapsed: 65.322 s, estimated 79.179 s:
# 0.825 elapsed: 65.536 s, estimated 79.197 s:
# 0.8275 elapsed: 65.734 s, estimated 79.197 s:
# 0.83 elapsed: 65.920 s, estimated 79.183 s:
# 0.8325 elapsed: 66.105 s, estimated 79.167 s:
# 0.835 elapsed: 66.289 s, estimated 79.151 s:
# 0.8375 elapsed: 66.478 s, estimated 79.141 s:
# 0.84 elapsed: 66.673 s, estimated 79.138 s:
# 0.8425 elapsed: 66.860 s, estimated 79.124 s:
# 0.845 elapsed: 67.055 s, estimated 79.121 s:
# 0.8475 elapsed: 67.251 s, estimated 79.119 s:
# 0.85 elapsed: 67.449 s, estimated 79.119 s:
# 0.8525 elapsed: 67.637 s, estimated 79.108 s:
# 0.855 elapsed: 67.825 s, estimated 79.097 s:
# 0.8575 elapsed: 68.015 s, estimated 79.088 s:
# 0.86 elapsed: 68.204 s, estimated 79.077 s:
# 0.8625 elapsed: 68.395 s, estimated 79.070 s:
# 0.865 elapsed: 68.594 s, estimated 79.071 s:
# 0.8675 elapsed: 68.792 s, estimated 79.071 s:
# 0.87 elapsed: 68.986 s, estimated 79.067 s:
# 0.8725 elapsed: 69.172 s, estimated 79.054 s:
# 0.875 elapsed: 69.367 s, estimated 79.051 s:
# 0.8775 elapsed: 69.568 s, estimated 79.054 s:
# 0.88 elapsed: 69.783 s, estimated 79.075 s:
# 0.8825 elapsed: 70.012 s, estimated 79.110 s:
# 0.885 elapsed: 70.206 s, estimated 79.106 s:
# 0.8875 elapsed: 70.400 s, estimated 79.101 s:
# 0.89 elapsed: 70.614 s, estimated 79.119 s:
# 0.8925 elapsed: 70.806 s, estimated 79.113 s:
# 0.895 elapsed: 70.998 s, estimated 79.107 s:
# 0.8975 elapsed: 71.193 s, estimated 79.103 s:
# 0.9 elapsed: 71.402 s, estimated 79.116 s:
# 0.9025 elapsed: 71.651 s, estimated 79.173 s:
# 0.905 elapsed: 71.854 s, estimated 79.178 s:
# 0.9075 elapsed: 72.049 s, estimated 79.175 s:
# 0.91 elapsed: 72.245 s, estimated 79.172 s:
# 0.9125 elapsed: 72.433 s, estimated 79.162 s:
# 0.915 elapsed: 72.635 s, estimated 79.166 s:
# 0.9175 elapsed: 72.867 s, estimated 79.203 s:
# 0.92 elapsed: 73.061 s, estimated 79.199 s:
# 0.9225 elapsed: 73.246 s, estimated 79.185 s:
# 0.925 elapsed: 73.438 s, estimated 79.178 s:
# 0.9275 elapsed: 73.634 s, estimated 79.176 s:
# 0.93 elapsed: 73.825 s, estimated 79.169 s:
# 0.9325 elapsed: 74.013 s, estimated 79.158 s:
# 0.935 elapsed: 74.204 s, estimated 79.151 s:
# 0.9375 elapsed: 74.392 s, estimated 79.141 s:
# 0.94 elapsed: 74.586 s, estimated 79.137 s:
# 0.9425 elapsed: 74.774 s, estimated 79.126 s:
# 0.945 elapsed: 74.962 s, estimated 79.115 s:
# 0.9475 elapsed: 75.152 s, estimated 79.107 s:
# 0.95 elapsed: 75.360 s, estimated 79.118 s:
# 0.9525 elapsed: 75.560 s, estimated 79.121 s:
# 0.955 elapsed: 75.750 s, estimated 79.112 s:
# 0.9575 elapsed: 75.941 s, estimated 79.105 s:
# 0.96 elapsed: 76.133 s, estimated 79.099 s:
# 0.9625 elapsed: 76.323 s, estimated 79.091 s:
# 0.965 elapsed: 76.515 s, estimated 79.086 s:
# 0.9675 elapsed: 76.729 s, estimated 79.103 s:
# 0.97 elapsed: 76.940 s, estimated 79.116 s:
# 0.9725 elapsed: 77.151 s, estimated 79.129 s:
# 0.975 elapsed: 77.360 s, estimated 79.141 s:
# 0.9775 elapsed: 77.598 s, estimated 79.182 s:
# 0.98 elapsed: 77.796 s, estimated 79.181 s:
# 0.9825 elapsed: 77.994 s, estimated 79.182 s:
# 0.985 elapsed: 78.201 s, estimated 79.190 s:
# 0.9875 elapsed: 78.389 s, estimated 79.181 s:
# 0.99 elapsed: 78.594 s, estimated 79.187 s:
# 0.9925 elapsed: 78.831 s, estimated 79.228 s:
# 0.995 elapsed: 79.041 s, estimated 79.239 s:

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure()
ax2 = fig.add_subplot(111)
quad1 = ax2.pcolormesh(x,y,eta[0,:,:],shading='gouraud',vmax=0.6)
ax2.contour(x,y,h,colors='k')

ax2.set_xlabel('time')
ax2.set_ylabel('amplitude')
cb2 = fig.colorbar(quad1,ax=ax2)
ax2.set_aspect('equal')
def init():
    quad1.set_array([])
    return quad1,


def animate(i):
    quad1.set_array(eta[i*10,:,:].ravel())
    return quad1,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=40, interval=100)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgFQADZXYKCDWJUNTR">
#     <br>
#     <input id="_anim_sliderFQADZXYKCDWJUNTR" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animFQADZXYKCDWJUNTR.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animFQADZXYKCDWJUNTR.slower()">&#8211;</button>
#     <button onclick="animFQADZXYKCDWJUNTR.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFQADZXYKCDWJUNTR.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFQADZXYKCDWJUNTR.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFQADZXYKCDWJUNTR.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animFQADZXYKCDWJUNTR.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFQADZXYKCDWJUNTR.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFQADZXYKCDWJUNTR.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animFQADZXYKCDWJUNTR.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectFQADZXYKCDWJUNTR" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgFQADZXYKCDWJUNTR";
#     var slider_id = "_anim_sliderFQADZXYKCDWJUNTR";
#     var loop_select_id = "_anim_loop_selectFQADZXYKCDWJUNTR";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animFQADZXYKCDWJUNTR = new Animation(frames, img_id, slider_id, 100, loop_select_id);
#     }, 0);
#   })()
# </script>

# %% [markdown]
# <a id="caso2"></a>
#
# # [Caso 2: Isla cónica](http://nctr.pmel.noaa.gov/benchmark/Laboratory/Laboratory_ConicalIsland/index.html)

# %%
def topo(x,y):
    """
    Conical island
    """
    # Depth of water: 0.32 or 0.42 meters for benchmarks.
    depth = 0.32
    r = np.sqrt(x**2 + y**2) 
    z = np.where(r < 1.1, 0.625, 0.625 - 0.25*(r-1.1))
    z = np.where(r < 3.6, z, 0.)
    z = z - depth
    return z

# %%
def qinit(x,y):
    """
    Wave approaching from left.
    (Used as initial test problem)
    """
    hjump = 0.3
#     z = np.where((x > -9.) & (x < -7.), hjump, 0.)
    z = 0.01*np.exp(-(x+8)**2)
    return z

# %%
nt = 200
ny = 100
nx = 125
y = np.linspace(-15,15,ny)
x = np.linspace(-22.5,15,nx)
x,y = np.meshgrid(x,y,indexing='ij')
h = -topo(x,y)

# %%
plt.pcolormesh(x,y,h)
plt.colorbar()

# %%
5/4000.

# %%
eta = np.zeros((nt,nx,ny))
eta[0,:,:] = 0.00*np.exp(-(x+10)**2/4) ##gaussian bell
eta[0,:,:] = np.where(h>=0,eta[0,:,:],-h)
plt.pcolormesh(x,y,eta[0,:,:],vmax=0.002)
plt.axis('equal')
plt.title(u'$\eta$',fontsize=26)
plt.colorbar()

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

fig = plt.figure(figsize=(9,6))
ax = fig.gca(projection='3d')
surf = ax.plot_surface(x,y,-h, rstride=1, cstride=1, cmap=cm.Greens_r,
                       linewidth=0.0, antialiased=False)
surf2 = ax.plot_surface(x,y,eta[0,:,:], rstride=1, cstride=1, cmap=cm.Blues_r,
                       linewidth=0.)
fig.colorbar(surf, shrink=0.5, aspect=5)

ax.set_axis_off()
ax.azim = -100.
ax.elev = 15

# %%
p = np.zeros((nt,nx,ny))
q = np.zeros((nt,nx,ny))
cfl = 0.45
dx = np.diff(x.T)[0,0]
dy = np.diff(y)[0,0]
dt = cfl*min(dx,dy)/np.sqrt(np.max(h)*9.81)
rx = dt/dx
ry = dt/dy
gx = 1e-5
grx = 9.81*dt/dx
gry = 9.81*dt/dy

# %%
eta,p,q = simulation(x,h,eta,p,q,rx,ry,dx,dy,cfl,nt,gx)
print 'finished!'

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure()
ax2 = fig.add_subplot(111)
quad1 = ax2.pcolormesh(x,y,eta[0,:,:],shading='gouraud',vmin=-0.002,vmax=0.002)
ax2.contour(x,y,h,colors='k')

ax2.set_xlabel('time')
ax2.set_ylabel('amplitude')
# ax2.set_xlim(-10,5)
# ax2.set_ylim(-5,5)
cb2 = fig.colorbar(quad1,ax=ax2)
ax2.set_aspect('equal')
def init():
    quad1.set_array([])
    return quad1,


def animate(i):
    quad1.set_array(eta[i*4,:,:].ravel())
    return quad1,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=50, interval=100)

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure()
ax2 = fig.add_subplot(111)
quad1 = ax2.pcolormesh(x,y,eta[0,:,:],shading='gouraud',vmin=-0.002,vmax=0.002)
ax2.contour(x,y,h,colors='k')

ax2.set_xlabel('time')
ax2.set_ylabel('amplitude')
ax2.set_xlim(-10,5)
ax2.set_ylim(-5,5)
cb2 = fig.colorbar(quad1,ax=ax2)
ax2.set_aspect('equal')
def init():
    quad1.set_array([])
    return quad1,


def animate(i):
    quad1.set_array(eta[i*4,:,:].ravel())
    return quad1,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=50, interval=100)

# %% [markdown]
# Falla el borde $j=ny$ y $i=0$

# %% [markdown]
# # Caso 3: Tsunami Chile 2010

# %%
from scipy.io import loadmat

# %%
h = loadmat('MorenoCS_h')
falla = loadmat('MorenoCS_z')

# %%
xb = h['xh'][0,0][0,:]
yb = h['yh'][0,0][0,:]
zb = h['zh'][0,0]
zf = falla['zf'][0,0]
xf = falla['xf'][0,0][0,:]
yf = falla['yf'][0,0][0,:]

# %%
# plt.figure(figsize=(9,9))
r = 6
print xb[::r].shape,yb[::r].shape,zb[::r,::r].shape
plt.subplot(121)
plt.pcolormesh(xb[::r],yb[::r],zb[::r,::r],vmin=-8000,vmax=6000)
plt.axis('equal')
plt.axis('off')
plt.subplot(122)
plt.pcolormesh(xf[::r],yf[::r],zf[::r,::r],vmin=0.0)
plt.axis('off')
plt.axis('equal')
plt.tight_layout()

# %%
r = 3
nt = 50
x = xb[::r] - xb.min()
y = yb[::r] - yb.min()
x,y = np.meshgrid(x,y,indexing='ij')
h = -zb[::r,::r].T
nx,ny = x.shape
plt.pcolormesh(x,y,-h)
plt.axis('equal')
plt.colorbar()
print nx,ny

# %%
eta = np.zeros((nt,nx,ny))
eta[0,:,:] = zf[::r,::r].T
eta[0,:,:] = np.where(eta[0,:,:]<0,0.0,eta[0,:,:])
eta[0,:,:] = np.where(h>gx,eta[0,:,:],-h)

plt.figure(figsize=(16,6))
plt.subplot(131)
plt.pcolormesh(x,y,zf[::r,::r].T,vmin=0.0)
plt.colorbar()
plt.axis('equal')
plt.subplot(132)
plt.pcolormesh(x,y,eta[0,:,:],vmax=4)
plt.axis('equal')
plt.title(u'$\eta$',fontsize=26)
plt.colorbar()
plt.subplot(133)
plt.pcolormesh(x,y,eta[0,:,:])
plt.axis('equal')
plt.title(u'$\eta$',fontsize=26)
plt.colorbar()
plt.tight_layout()

# %%
p = np.zeros((nt,nx,ny))
q = np.zeros((nt,nx,ny))
cfl = 0.45
dx = np.diff(x.T)[0,0]
dy = np.diff(y)[0,0]
dt = cfl*min(dx,dy)/np.sqrt(np.max(h)*9.81)
rx = dt/dx
ry = dt/dy
gx = 1e-2
grx = 9.81*dt/dx
gry = 9.81*dt/dy

# %%
eta,p,q = simulation(x,h,eta,p,q,rx,ry,dx,dy,cfl,nt,gx)
print 'finished!'

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure(figsize=(12,12))
ax2 = fig.add_subplot(111)
quad1 = ax2.pcolormesh(x,y,eta[0,:,:],shading='gouraud',vmax=5.)
ax2.contour(x,y,h,colors='k')

ax2.set_xlabel('time')
ax2.set_ylabel('amplitude')
# ax2.set_xlim(-10,5)
# ax2.set_ylim(-5,5)
cb2 = fig.colorbar(quad1,ax=ax2)
ax2.set_aspect('equal')
def init():
    quad1.set_array([])
    return quad1,


def animate(i):
    quad1.set_array(eta[i*2,:,:].ravel())
    return quad1,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=25, interval=100)

# %%
plt.pcolormesh(-h,vmax=0.)
