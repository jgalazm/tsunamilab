# %% [markdown]
# # Contenido (hipervínculos)

# %% [markdown]
# 1. <a href="L2D"> Modelo </a>
#
# 2. <a href="#caso1">Caso 1: Cilindro sumergido</a>
#
# 3. <a href="#caso2"> Caso 2: Isla cónica (NOAA)</a>
#
# 4. <a href="#caso3"> Caso 3: Chile 2010 (Moreno)</a>

# %%
import time

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy.io import loadmat

# %% [markdown]
# # Simple case

# %%
R_earth = 6378000.
rad_deg = 0.01745329252
rad_min = 0.000290888208665721
cori_w = 7.2722e-5
g = 9.81
gx  =1e-1

# %%
import utm

# %%
x = np.linspace(-30,30.0,61) #in degrees
y = np.linspace(-30,30.0,61)
xmesh, ymesh = np.meshgrid(x,y,indexing='ij')

nx = x.shape[0]
ny = y.shape[0]
dx = np.diff(x)[0]*60 #in minutes
dy = np.diff(y)[0]*60 #in minutes
lat_max = max(abs(y[0]),abs(y[-1]))*rad_deg
dx_real = R_earth*np.cos(lat_max)*dx*rad_min
dy_real = R_earth*dy*rad_min
dt = 0.45*min(dx_real,dy_real)/np.sqrt(g*h0)
print dt
# Out:
# 234.118914649

# %%
h = np.ones_like(xmesh)*1000
L = x.max()-x.min()
h = np.where(xmesh**2+ymesh**2<=(L/6)**2,5000,h)
plt.pcolormesh(xmesh,ymesh,h)
plt.axis('equal')
# Out:
# (-30.0, 30.0, -30.0, 30.0)

# %%
RR = dt/R_earth
angM = ymesh*rad_deg
cosM = np.cos(angM)
sinM = np.sin(angM)
R1 = RR/(cosM*dx*rad_min)
R11 = RR/(cosM*dy*rad_min)
R6 = np.cos((ymesh+0.5*dy/60.0)*rad_deg)
print 'RR',RR
print 'R1',R1.min(),R1.max()
print 'R11', R11.min(),R11.max()
print 'R6', R6.min(), R6.max()
# Out:
# RR 3.67072616258e-05
# R1 0.00210317116864 0.00242853288074
# R11 0.00210317116864 0.00242853288074
# R6 0.861629160441 0.999961923064

# %%
RS = g*RR
hp = h*1.0
hp[0:-1,:] = 0.5*(h[0:-1,:]+h[1:,:])
R2 = np.where(hp>0,RS/(cosM*dx*rad_min)*hp,0.0)
RT = 0.5*dt*cori_w
R3 = RT*sinM
print 'R2',R2.min(),R2.max()
print 'R3',R3.min(),R3.max()
# Out:
# R2 20.6321091644 104.446455002
# R3 -0.0042563989278 0.0042563989278

# %%
angN = (ymesh + 0.5*dy/60.)*rad_deg
sinN = np.sin(angN)
hq = h*1.0
hq[:,0:-1] = 0.5*(h[:,0:-1]+h[:,1:])
R4 = np.where(hq>0,RS/(dy*rad_min)*hq,0.0)
R5 = RT*sinN

# %%
nt = 210
eta = np.zeros((nt,nx,ny))
p = np.zeros_like(eta)
q = np.zeros_like(eta)

xmid = 0.3*x.max()+0.7*x.min()
ymid = 0.3*y.max()+0.7*y.min()
L = 0.15*(y.max()-y.min())
eta[0,:,:] = np.exp(-((xmesh-xmid)**2+(ymesh-ymid)**2)/L**2)

# eta[0,:,:] = np.exp(-((xmesh+27)**2+(y+27)**2)/10)*5.0
# eta[0,:,:] = np.where(h>0,eta[0,:,:],-h)

# %%
plt.pcolormesh(xmesh,ymesh,eta[0,:,:])
plt.colorbar()
plt.axis('equal')
# Out:
# (-30.0, 30.0, -30.0, 30.0)

# %%
def simulation(x,h,eta,p,q,R1,R11,R6,R2,R4,R5,nt,gx,debug=False):
    dp1 = np.zeros_like(x)
    dp2 = np.zeros_like(x)
    dq1 = np.zeros_like(x)
    dq2 = np.zeros_like(x)

    zdepth = np.zeros_like(eta)
    zdepth[0,:,:] = eta[0,:,:]+h

    t0 = time.clock()
    for n in range(nt-1):
        ## Mas Loop
        for i in range(1, nx-1):
            for j in range(1, ny-1):
                if (h[i,j]>gx):
                    zzz = eta[n,i,j] - R1[i,j]*(p[n,i,j]-p[n,i-1,j]) \
                                   - R11[i,j]*(q[n,i,j]*R6[i,j]-q[n,i,j-1]*R6[i,j-1])
                    DD = zzz + h[i,j]
                    zdepth[n+1,i,j] = DD
                    eta[n+1,i,j] = zzz    
                else:
                    eta[n+1,i,j] = 0.0
                    
        # open boundary
        
        j = 0
        for i in range(1,nx-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                uh = 0.5*(p[n,i,j]+p[n,i-1,j])
                uu = np.sqrt(uh**2+q[n,i,j]**2)
                zz = uu/cc
                if q[n,i,j]>0:
                    zz = -zz
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]                        

        j = ny-1
        for i in range(1,nx-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                uh = 0.5*(p[n,i,j]+p[n,i-1,j])
                uu = np.sqrt(uh**2+q[n,i,j-1]**2)
                zz = uu/cc
                if q[n,i,j-1]<0:
                    zz = -zz
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]                

        i = 0
        for j in range(1,ny-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                if h[i,j-1]>gx:
                    uh = 0.5*(q[n,i,j]+q[n,i,j-1])
                else:
                    uh = q[n,i,j]
                uu = np.sqrt(uh**2+p[n,i,j]**2)
                zz = uu/cc
                if p[n,i,j]>0:
                    zz = -zz
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]

        i = nx-1
        for j in range(1,ny-1):
            if h[i,j]>gx:
                cc = np.sqrt(9.81*h[i,j])
                uh = 0.5*(q[n,i,j]+q[n,i,j-1])
                uu = np.sqrt(uh**2+p[n,i-1,j]**2)
                zz = uu/cc
                if p[n,i-1,j]<0:
                    zz = -zz
                eta[n+1,i,j] = zz     
                zdepth[n+1,i,j] = zz+h[i,j]
            else:
                zz = 0.0
                eta[n+1,i,j] = zz
                zdepth[n+1,i,j] = zz+h[i,j]


        i = 0
        j = 0
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i,j]
            qy = q[n,i,j]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx>0 or qy>0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]           

        i = nx-1
        j = 0
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i-1,j]
            qy = q[n,i,j]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx<0 or qy>0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]                 

        i = 0
        j = ny-1
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i,j]
            qy = q[n,i,j-1]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx>0 or qy<0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]

        i = nx-1
        j = ny-1
        if h[i,j]>gx:
            cc = np.sqrt(9.81*h[i,j])
            qx = p[n,i-1,j]
            qy = q[n,i,j-1]
            uu = np.sqrt(qx**2+qy**2)        
            zz = uu/cc
            if qx<0 or qy<0:
                zz = -zz
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]
        else:
            zz = 0.0
            eta[n+1,i,j] = zz
            zdepth[n+1,i,j] = zz+h[i,j]                         

        # momentum loop

        # momentum in x-direction
        for i in range(0,nx-1):
            for j in range(0,ny-1):
                ip1 = min(nx-1,i+1)
                jp1 = max(0,i-1)

                if h[i,j]>gx and h[ip1,j]>gx:
                    hM = 0.5*(h[i,j]+h[ip1,j]) + 0.5 *(eta[n+1,i,j]+eta[n+1,ip1,j])

                    p[n+1,i,j]  = p[n,i,j] - R2[i,j]* (eta[n+1,ip1,j]-eta[n+1,i,j])
                else:
                    p[n+1,i,j] = 0.0

        # momentum in y-direction
        for i in range(0,nx-1):
            for j in range(0,ny-1):
                ip1 = min(nx-1,i+1)
                jp1 = min(ny-1,j+1)

                if h[i,j]>gx and h[i,jp1]>gx:
    #                     hN = 0.5*(h[i,j]+h[i,jp1]) + 0.5 *(eta[n+1,i,j]+eta[n+1,i,jp1])
                    q[n+1,i,j]  = q[n,i,j] - R4[i,j]*(eta[n+1,i,jp1]-eta[n+1,i,j])
                else:
                    q[n+1,i,j] = 0.0  

        t1 = time.clock()    

        print '%.3f'%(n*1.0/nt), 'elapsed: %.3f s, estimated %.3f s:'%(t1-t0,(t1-t0)*nt*1.0/(n+1))
    return eta,p,q

# %%
eta,p,q = simulation(x,h,eta,p,q,R1,R11,R6,R2,R4,R5,nt,gx)
# Out:
# 0.000 elapsed: 0.078 s, estimated 16.297 s:
# 0.005 elapsed: 0.117 s, estimated 12.332 s:
# 0.010 elapsed: 0.151 s, estimated 10.572 s:
# 0.014 elapsed: 0.191 s, estimated 10.006 s:
# 0.019 elapsed: 0.224 s, estimated 9.416 s:
# 0.024 elapsed: 0.263 s, estimated 9.213 s:
# 0.029 elapsed: 0.304 s, estimated 9.105 s:
# 0.033 elapsed: 0.343 s, estimated 9.001 s:
# 0.038 elapsed: 0.377 s, estimated 8.786 s:
# 0.043 elapsed: 0.416 s, estimated 8.732 s:
# 0.048 elapsed: 0.450 s, estimated 8.582 s:
# 0.052 elapsed: 0.489 s, estimated 8.553 s:
# 0.057 elapsed: 0.523 s, estimated 8.441 s:
# 0.062 elapsed: 0.561 s, estimated 8.422 s:
# 0.067 elapsed: 0.595 s, estimated 8.331 s:
# 0.071 elapsed: 0.634 s, estimated 8.325 s:
# 0.076 elapsed: 0.668 s, estimated 8.254 s:
# 0.081 elapsed: 0.707 s, estimated 8.249 s:
# 0.086 elapsed: 0.741 s, estimated 8.190 s:
# 0.090 elapsed: 0.780 s, estimated 8.191 s:
# 0.095 elapsed: 0.814 s, estimated 8.141 s:
# 0.100 elapsed: 0.853 s, estimated 8.141 s:
# 0.105 elapsed: 0.888 s, estimated 8.110 s:
# 0.110 elapsed: 0.927 s, estimated 8.111 s:
# 0.114 elapsed: 0.961 s, estimated 8.069 s:
# 0.119 elapsed: 1.002 s, estimated 8.094 s:
# 0.124 elapsed: 1.036 s, estimated 8.057 s:
# 0.129 elapsed: 1.076 s, estimated 8.068 s:
# 0.133 elapsed: 1.113 s, estimated 8.059 s:
# 0.138 elapsed: 1.151 s, estimated 8.060 s:
# 0.143 elapsed: 1.185 s, estimated 8.029 s:
# 0.148 elapsed: 1.227 s, estimated 8.051 s:
# 0.152 elapsed: 1.266 s, estimated 8.053 s:
# 0.157 elapsed: 1.301 s, estimated 8.034 s:
# 0.162 elapsed: 1.344 s, estimated 8.066 s:
# 0.167 elapsed: 1.379 s, estimated 8.044 s:
# 0.171 elapsed: 1.413 s, estimated 8.019 s:
# 0.176 elapsed: 1.448 s, estimated 8.000 s:
# 0.181 elapsed: 1.481 s, estimated 7.976 s:
# 0.186 elapsed: 1.516 s, estimated 7.959 s:
# 0.190 elapsed: 1.550 s, estimated 7.937 s:
# 0.195 elapsed: 1.584 s, estimated 7.922 s:
# 0.200 elapsed: 1.618 s, estimated 7.902 s:
# 0.205 elapsed: 1.653 s, estimated 7.887 s:
# 0.210 elapsed: 1.686 s, estimated 7.870 s:
# 0.214 elapsed: 1.726 s, estimated 7.881 s:
# 0.219 elapsed: 1.764 s, estimated 7.884 s:
# 0.224 elapsed: 1.805 s, estimated 7.896 s:
# 0.229 elapsed: 1.839 s, estimated 7.882 s:
# 0.233 elapsed: 1.874 s, estimated 7.870 s:
# 0.238 elapsed: 1.909 s, estimated 7.860 s:
# 0.243 elapsed: 1.944 s, estimated 7.849 s:
# 0.248 elapsed: 1.977 s, estimated 7.834 s:
# 0.252 elapsed: 2.012 s, estimated 7.826 s:
# 0.257 elapsed: 2.046 s, estimated 7.812 s:
# 0.262 elapsed: 2.080 s, estimated 7.802 s:
# 0.267 elapsed: 2.114 s, estimated 7.789 s:
# 0.271 elapsed: 2.149 s, estimated 7.781 s:
# 0.276 elapsed: 2.182 s, estimated 7.768 s:
# 0.281 elapsed: 2.217 s, estimated 7.759 s:
# 0.286 elapsed: 2.251 s, estimated 7.750 s:
# 0.290 elapsed: 2.286 s, estimated 7.742 s:
# 0.295 elapsed: 2.319 s, estimated 7.731 s:
# 0.300 elapsed: 2.366 s, estimated 7.765 s:
# 0.305 elapsed: 2.406 s, estimated 7.773 s:
# 0.310 elapsed: 2.440 s, estimated 7.765 s:
# 0.314 elapsed: 2.474 s, estimated 7.754 s:
# 0.319 elapsed: 2.509 s, estimated 7.748 s:
# 0.324 elapsed: 2.542 s, estimated 7.737 s:
# 0.329 elapsed: 2.577 s, estimated 7.731 s:
# 0.333 elapsed: 2.610 s, estimated 7.721 s:
# 0.338 elapsed: 2.645 s, estimated 7.715 s:
# 0.343 elapsed: 2.679 s, estimated 7.706 s:
# 0.348 elapsed: 2.714 s, estimated 7.701 s:
# 0.352 elapsed: 2.747 s, estimated 7.693 s:
# 0.357 elapsed: 2.783 s, estimated 7.690 s:
# 0.362 elapsed: 2.817 s, estimated 7.684 s:
# 0.367 elapsed: 2.853 s, estimated 7.681 s:
# 0.371 elapsed: 2.888 s, estimated 7.676 s:
# 0.376 elapsed: 2.923 s, estimated 7.674 s:
# 0.381 elapsed: 2.958 s, estimated 7.668 s:
# 0.386 elapsed: 2.994 s, estimated 7.668 s:
# 0.390 elapsed: 3.031 s, estimated 7.669 s:
# 0.395 elapsed: 3.067 s, estimated 7.667 s:
# 0.400 elapsed: 3.101 s, estimated 7.661 s:
# 0.405 elapsed: 3.136 s, estimated 7.658 s:
# 0.410 elapsed: 3.173 s, estimated 7.659 s:
# 0.414 elapsed: 3.210 s, estimated 7.661 s:
# 0.419 elapsed: 3.246 s, estimated 7.658 s:
# 0.424 elapsed: 3.285 s, estimated 7.664 s:
# 0.429 elapsed: 3.320 s, estimated 7.661 s:
# 0.433 elapsed: 3.355 s, estimated 7.658 s:
# 0.438 elapsed: 3.396 s, estimated 7.667 s:
# 0.443 elapsed: 3.431 s, estimated 7.664 s:
# 0.448 elapsed: 3.465 s, estimated 7.659 s:
# 0.452 elapsed: 3.500 s, estimated 7.657 s:
# 0.457 elapsed: 3.534 s, estimated 7.652 s:
# 0.462 elapsed: 3.569 s, estimated 7.649 s:
# 0.467 elapsed: 3.603 s, estimated 7.643 s:
# 0.471 elapsed: 3.638 s, estimated 7.639 s:
# 0.476 elapsed: 3.671 s, estimated 7.633 s:
# 0.481 elapsed: 3.706 s, estimated 7.630 s:
# 0.486 elapsed: 3.740 s, estimated 7.625 s:
# 0.490 elapsed: 3.775 s, estimated 7.622 s:
# 0.495 elapsed: 3.809 s, estimated 7.618 s:
# 0.500 elapsed: 3.853 s, estimated 7.634 s:
# 0.505 elapsed: 3.892 s, estimated 7.638 s:
# 0.510 elapsed: 3.934 s, estimated 7.649 s:
# 0.514 elapsed: 3.987 s, estimated 7.681 s:
# 0.519 elapsed: 4.051 s, estimated 7.733 s:
# 0.524 elapsed: 4.109 s, estimated 7.774 s:
# 0.529 elapsed: 4.156 s, estimated 7.792 s:
# 0.533 elapsed: 4.200 s, estimated 7.806 s:
# 0.538 elapsed: 4.242 s, estimated 7.814 s:
# 0.543 elapsed: 4.283 s, estimated 7.820 s:
# 0.548 elapsed: 4.326 s, estimated 7.831 s:
# 0.552 elapsed: 4.374 s, estimated 7.850 s:
# 0.557 elapsed: 4.424 s, estimated 7.873 s:
# 0.562 elapsed: 4.467 s, estimated 7.883 s:
# 0.567 elapsed: 4.520 s, estimated 7.910 s:
# 0.571 elapsed: 4.580 s, estimated 7.948 s:
# 0.576 elapsed: 4.630 s, estimated 7.970 s:
# 0.581 elapsed: 4.681 s, estimated 7.992 s:
# 0.586 elapsed: 4.722 s, estimated 7.997 s:
# 0.590 elapsed: 4.759 s, estimated 7.995 s:
# 0.595 elapsed: 4.794 s, estimated 7.990 s:
# 0.600 elapsed: 4.833 s, estimated 7.991 s:
# 0.605 elapsed: 4.869 s, estimated 7.989 s:
# 0.610 elapsed: 4.908 s, estimated 7.990 s:
# 0.614 elapsed: 4.945 s, estimated 7.988 s:
# 0.619 elapsed: 4.981 s, estimated 7.985 s:
# 0.624 elapsed: 5.016 s, estimated 7.980 s:
# 0.629 elapsed: 5.052 s, estimated 7.977 s:
# 0.633 elapsed: 5.086 s, estimated 7.971 s:
# 0.638 elapsed: 5.121 s, estimated 7.967 s:
# 0.643 elapsed: 5.156 s, estimated 7.961 s:
# 0.648 elapsed: 5.191 s, estimated 7.957 s:
# 0.652 elapsed: 5.225 s, estimated 7.950 s:
# 0.657 elapsed: 5.260 s, estimated 7.947 s:
# 0.662 elapsed: 5.294 s, estimated 7.941 s:
# 0.667 elapsed: 5.329 s, estimated 7.937 s:
# 0.671 elapsed: 5.363 s, estimated 7.931 s:
# 0.676 elapsed: 5.398 s, estimated 7.927 s:
# 0.681 elapsed: 5.436 s, estimated 7.928 s:
# 0.686 elapsed: 5.472 s, estimated 7.925 s:
# 0.690 elapsed: 5.506 s, estimated 7.919 s:
# 0.695 elapsed: 5.541 s, estimated 7.915 s:
# 0.700 elapsed: 5.575 s, estimated 7.911 s:
# 0.705 elapsed: 5.610 s, estimated 7.907 s:
# 0.710 elapsed: 5.645 s, estimated 7.903 s:
# 0.714 elapsed: 5.688 s, estimated 7.911 s:
# 0.719 elapsed: 5.723 s, estimated 7.906 s:
# 0.724 elapsed: 5.757 s, estimated 7.902 s:
# 0.729 elapsed: 5.791 s, estimated 7.897 s:
# 0.733 elapsed: 5.825 s, estimated 7.892 s:
# 0.738 elapsed: 5.859 s, estimated 7.887 s:
# 0.743 elapsed: 5.894 s, estimated 7.884 s:
# 0.748 elapsed: 5.929 s, estimated 7.881 s:
# 0.752 elapsed: 5.964 s, estimated 7.877 s:
# 0.757 elapsed: 5.998 s, estimated 7.872 s:
# 0.762 elapsed: 6.036 s, estimated 7.873 s:
# 0.767 elapsed: 6.070 s, estimated 7.869 s:
# 0.771 elapsed: 6.105 s, estimated 7.865 s:
# 0.776 elapsed: 6.138 s, estimated 7.860 s:
# 0.781 elapsed: 6.173 s, estimated 7.857 s:
# 0.786 elapsed: 6.206 s, estimated 7.852 s:
# 0.790 elapsed: 6.241 s, estimated 7.848 s:
# 0.795 elapsed: 6.275 s, estimated 7.843 s:
# 0.800 elapsed: 6.309 s, estimated 7.840 s:
# 0.805 elapsed: 6.343 s, estimated 7.835 s:
# 0.810 elapsed: 6.377 s, estimated 7.832 s:
# 0.814 elapsed: 6.411 s, estimated 7.827 s:
# 0.819 elapsed: 6.453 s, estimated 7.833 s:
# 0.824 elapsed: 6.486 s, estimated 7.828 s:
# 0.829 elapsed: 6.521 s, estimated 7.825 s:
# 0.833 elapsed: 6.555 s, estimated 7.821 s:
# 0.838 elapsed: 6.589 s, estimated 7.818 s:
# 0.843 elapsed: 6.626 s, estimated 7.817 s:
# 0.848 elapsed: 6.661 s, estimated 7.814 s:
# 0.852 elapsed: 6.695 s, estimated 7.811 s:
# 0.857 elapsed: 6.730 s, estimated 7.808 s:
# 0.862 elapsed: 6.764 s, estimated 7.804 s:
# 0.867 elapsed: 6.798 s, estimated 7.801 s:
# 0.871 elapsed: 6.832 s, estimated 7.797 s:
# 0.876 elapsed: 6.866 s, estimated 7.794 s:
# 0.881 elapsed: 6.900 s, estimated 7.790 s:
# 0.886 elapsed: 6.935 s, estimated 7.788 s:
# 0.890 elapsed: 6.969 s, estimated 7.784 s:
# 0.895 elapsed: 7.004 s, estimated 7.782 s:
# 0.900 elapsed: 7.038 s, estimated 7.779 s:
# 0.905 elapsed: 7.072 s, estimated 7.776 s:
# 0.910 elapsed: 7.107 s, estimated 7.774 s:
# 0.914 elapsed: 7.142 s, estimated 7.771 s:
# 0.919 elapsed: 7.176 s, estimated 7.768 s:
# 0.924 elapsed: 7.211 s, estimated 7.766 s:
# 0.929 elapsed: 7.245 s, estimated 7.762 s:
# 0.933 elapsed: 7.280 s, estimated 7.760 s:
# 0.938 elapsed: 7.313 s, estimated 7.756 s:
# 0.943 elapsed: 7.348 s, estimated 7.754 s:
# 0.948 elapsed: 7.381 s, estimated 7.750 s:
# 0.952 elapsed: 7.416 s, estimated 7.748 s:
# 0.957 elapsed: 7.457 s, estimated 7.752 s:
# 0.962 elapsed: 7.493 s, estimated 7.751 s:
# 0.967 elapsed: 7.526 s, estimated 7.748 s:
# 0.971 elapsed: 7.561 s, estimated 7.745 s:
# 0.976 elapsed: 7.595 s, estimated 7.742 s:
# 0.981 elapsed: 7.629 s, estimated 7.740 s:
# 0.986 elapsed: 7.663 s, estimated 7.737 s:
# 0.990 elapsed: 7.698 s, estimated 7.734 s:

# %%
from matplotlib import animation
from JSAnimation import IPython_display

fig = plt.figure(figsize=(6,6))
ax2 = fig.add_subplot(111)
quad1 = ax2.pcolormesh(xmesh,ymesh,eta[0,:,:],vmax=eta.max(),vmin=eta.min(),
                       shading='gouraud',cmap=plt.cm.seismic)
# plt.pcolormesh(xmesh,ymesh,np.ma.masked_where(h>0,-h),vmin=0.0,vmax=8000, cmap=plt.cm.Greens_r)
ax2.contour(xmesh,ymesh,h,[h.min()],colors='k')
# ax2.contour(xmesh,ymesh,h,[-10.,-100.,-1000.],colors='w')
# ax2.set_axis_off()
t = ax2.set_title('Time = %.2f min'%(0.0))
# ax2.set_xlim(-10,5)
# ax2.set_ylim(-5,5)
cb2 = fig.colorbar(quad1,ax=ax2)
ax2.set_aspect('equal')
def init():
    quad1.set_array([])
    return quad1,


def animate(i):
    j = i*10
    t.set_text('Time = %.2f min'%(j*dt/60))
    quad1.set_array(np.ma.masked_where(h<0,eta[j,:,:]).ravel())
    return quad1,

animation.FuncAnimation(fig, animate, init_func=init,
                        frames=20, interval=10)
# Out:
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgVMQELIXJMKPSRVLX">
#     <br>
#     <input id="_anim_sliderVMQELIXJMKPSRVLX" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animVMQELIXJMKPSRVLX.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animVMQELIXJMKPSRVLX.slower()">&#8211;</button>
#     <button onclick="animVMQELIXJMKPSRVLX.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVMQELIXJMKPSRVLX.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVMQELIXJMKPSRVLX.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVMQELIXJMKPSRVLX.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animVMQELIXJMKPSRVLX.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVMQELIXJMKPSRVLX.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVMQELIXJMKPSRVLX.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animVMQELIXJMKPSRVLX.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectVMQELIXJMKPSRVLX" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgVMQELIXJMKPSRVLX";
#     var slider_id = "_anim_sliderVMQELIXJMKPSRVLX";
#     var loop_select_id = "_anim_loop_selectVMQELIXJMKPSRVLX";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#
#
#     /* set a timeout to make sure all the above elements are created before
#        the object is initialized. */
#     setTimeout(function() {
#         animVMQELIXJMKPSRVLX = new Animation(frames, img_id, slider_id, 10, loop_select_id);
#     }, 0);
#   })()
# </script>

# %% [markdown]
# Comparar masa

# %%
print 'rx vs R1',R1.min(),R1.max()
print 'ry vs R11*R6',(R11*R6).min(),(R11*R6).max()
# Out:
# rx vs R1 0.00210317116864 0.00242853288074
# ry vs R11*R6 0.00209249474713 0.00211368742552

# %% [markdown]
# Comparar momentum

# %%
print 'grxH vs R2', R2.min(), R2.max()
print 'gryH vs R4', R4.min(), R4.max()
# Out:
# grxH vs R2 0.0206321091644 0.02382390756
# gryH vs R4 0.0206321091644 0.0206321091644

# %% [markdown]
# $\Delta x$ real

# %%
R_earth*dx*rad_min
# Out:
# 111317.09969219811

# %% [markdown]
# El R2 teórico

# %%
9.81*h.min()*dt/(R_earth*dx*rad_min), R2.min()
# Out:
# (20.632109164372707, 0.020632109164372713)

# %%
R2.min()
# Out:
# 0.020632109164372713
